# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 한국어 감정 정보가 포함된 단발성 대화 데이터셋
#
# (https://aihub.or.kr/opendata/keti-data/recognition-laguage/KETI-02-009)

# %%
keti_single=pd.read_excel('한국어_단발성_대화_데이터셋.xlsx')
keti_single.head()
# Out:
#                    Sentence Emotion  Unnamed: 2  Unnamed: 3  Unnamed: 4  공포  \
# 0  언니 동생으로 부르는게 맞는 일인가요..??      공포         NaN         NaN         NaN  놀람
# 1              그냥 내 느낌일뿐겠지?      공포         NaN         NaN         NaN  분노
# 2            아직너무초기라서 그런거죠?      공포         NaN         NaN         NaN  슬픔
# 3             유치원버스 사고 낫다던데      공포         NaN         NaN         NaN  중립
# 4               근데 원래이런거맞나요      공포         NaN         NaN         NaN  행복
#
#      5468
# 0  5898.0
# 1  5665.0
# 2  5267.0
# 3  4830.0
# 4  6037.0

# %%
keti_single=keti_single.iloc[:,:2]
keti_single.head()
# Out:
#                    Sentence Emotion
# 0  언니 동생으로 부르는게 맞는 일인가요..??      공포
# 1              그냥 내 느낌일뿐겠지?      공포
# 2            아직너무초기라서 그런거죠?      공포
# 3             유치원버스 사고 낫다던데      공포
# 4               근데 원래이런거맞나요      공포

# %%
keti_single.rename(columns={'Sentence':"발화",'Emotion':'감정'},inplace=True)

# %%
keti_single[keti_single["감정"]=="놀람"].sample(50)
# Out:
#                                                       발화  감정
# 9489   에혀. ..우리나라 국민도 인권대우 그닥인디....뭘 어쩌라고? 열악? 우리가 더 ...  놀람
# 7832                                 세상에나.....여기 어디학교지??  놀람
# 6519                                          와 류준열 소다 소  놀람
# 7836                                    뉴트리아는가고 불가사리각이냐?  놀람
# 8253                     야구라는 스포츠는 망하게 놔두고 저딴승마에는 200억 ㄷ  놀람
# 9380                                         무슨암이지?.....  놀람
# 7814                                   국방 외교 법무 안썩은데가.없네  놀람
# 7485                                        그러면 안되그래도 되?  놀람
# 6757                           롯데야 어떻게 그리 못할 수가 있냐??????  놀람
# 10616                     술마시고 혼자 빠졌나보네 여자나남자나 술좀 적당히 ㅠㅠ  놀람
# 10726  블랙리스트???? 좀더 알아봐여. 하두 조작을 많이 해서 믿을수 있어야쥐. 언론도 ...  놀람
# 5903                                      타잔인줄..........  놀람
# 8100                                                지진??  놀람
# 10404                                계좌로부쳐달랫더니 직접오라고햇습니다  놀람
# 5511                                          왜 하필 대구일까?  놀람
# 8587                     저 가격이면 미국이랑 같은 가격에 판다는 소리 아닌가??  놀람
# 10358                          저지금 제글 보다가 깜짝놀랐네요ㅋㅋㅋㅋㅋㅋㅋㅋ  놀람
# 8763                    생각하고잇엇는데달력을보니깐 출산이 3개월앞으로다가왓네요..  놀람
# 8370                      유럽에선 자전거에다 사람이 배달통을 짊어지고 하네...  놀람
# 5728                             언제부터 여기가 지금은 연애중으로 바꼈지?  놀람
# 10289                           정말 지금 충격이라 본문도 제대로 못쓰겠네요  놀람
# 8053                                   김태희글씨체 나랑 비슷해서 깜놀  놀람
# 7121   뉴스에 나오는 미국 블프에서 국내 대기업 tv가 할인율이 최대70~80프로라며 불티...  놀람
# 6390                          우리때는 병장 2만3천원인뎅 지금은 21만원 와  놀람
# 7908                        저사람 성폭행범도 본인손으로 총살시킴 클라스 개오짐  놀람
# 8853                                              꽃뱀입니까?  놀람
# 6375                               이런걸 열심히하는사람이 이리도많을줄이야  놀람
# 10793                              얼굴만 보면 어떻게 배우가 됐을까 의문  놀람
# 7034                                이정도 공감못하면 사이코패스아니에요?  놀람
# 5717                      들어와서 둘러보길레 잘못한것도 없는데 찔끔햇네 ㅋㅋㅋㅋ  놀람
# 10435                             헤어샵.옷 같은건 무료로 대여해주나요??  놀람
# 11299                       우리나라최고의 타자가 메이저에선 마이너수준이란말인가  놀람
# 7338                   박지훈 직캠 조회수 올라갔다 내려갔다 이상한거 같은데 ...  놀람
# 8363                                   김상수 팔 생각까지하고 있는거네  놀람
# 11070                     유럽애들 디젤은 전부 우리나라에다 쏟아내는 구나....  놀람
# 10518                                      희대의 대통령이닷!!!!  놀람
# 9852                                       방탄이 엑소 초동 이김?  놀람
# 5825       와쥐같은 대형기획사에서 이런 이벤트를 기획했다니 ;;;;;;;; 충격이다 ;;;;  놀람
# 8511                                         이건 정말 혁신이네.  놀람
# 6634                             치매야 사기꾼이야?????,????,,?,  놀람
# 7893                                          짤린건가??????  놀람
# 7790                                 ?? : 언니 여기다 댓글달면 되?  놀람
# 7973                                  선실 내 떠 있다...??????  놀람
# 9224                                    로또당첨되면 세금 40프로??  놀람
# 8043                                       형제는 용감했다.....  놀람
# 6506                                 리베이트받으면서 통과시켜준게아니고?  놀람
# 10646                                    역시 서장훈!!! 멋짐!!!  놀람
# 8635                                        저걸 도로에서 탄다고?  놀람
# 8789                                  전문가형도 이제 슬슬 밀리는구나!  놀람
# 9754        솔직히 여기서 연봉 5000못넘는 루저들은 조용히 댓글 삭제해라 ㅋㅋㅋㅋㅋㅋㅋㅋ  놀람

# %%
# "놀람"에 해당하는 텍스트들이 "중립","혐오","당황" 등을 넘나들기 때문에 "놀람"에 해당하는 데이터들을 삭제한다.

keti_single=keti_single[keti_single["감정"]!="놀람"]

# %%
keti_single["감정"]=np.where(keti_single["감정"].str.match("공포"),"불안",keti_single["감정"])

# %% [markdown]
# # 감성대화 말뭉치
# (https://aihub.or.kr/aidata/7978)

# %%
 fin_t=pd.read_excel('감성대화말뭉치(최종데이터)_Training.xlsx')
fin_v=pd.read_excel('감성대화말뭉치(최종데이터)_Validation.xlsx')

# %%
fin_t=fin_t.fillna("")
fin_v=fin_v.fillna("")

# %%
# 컬럼간 str 합치기

fin_t["사람문장"]=fin_t["사람문장1"].astype(str)+fin_t["사람문장2"].astype(str).astype(str)
fin_v["사람문장"]=fin_v["사람문장1"].astype(str)+fin_v["사람문장2"].astype(str).astype(str)

# %%
df_concat=pd.concat([fin_t,fin_v])

# %%
final_df=df_concat[["사람문장","감정_대분류"]]

# %%
final_df=final_df.rename({"감정_대분류":"감정"},axis=1)

# %%
#컬럼 내 데이터들의 공백(string) 제거

final_df["감정"]=final_df["감정"].apply(lambda x:x.strip())

# %%
final_df["감정"].value_counts()
# Out:
# 감정
# 불안    10433
# 분노    10417
# 상처    10150
# 슬픔    10128
# 당황     9804
# 기쁨     7339
# Name: count, dtype: int64

# %%
#np.where(조건,True일때 값,False일때 값)

final_df["감정"]=np.where(final_df["감정"].str.match("상처"),"슬픔",final_df["감정"])
final_df["감정"]=np.where(final_df["감정"].str.match("기쁨"),"행복",final_df["감정"])

# %%
final_df=final_df.reset_index(drop=True)

# %%
final_df.rename({"사람문장":"발화"},axis=1,inplace=True)

# %% [markdown]
# # 한국어 감정 정보 연속적 대화 데이터셋
# (https://aihub.or.kr/opendata/keti-data/recognition-laguage/KETI-02-010)

# %%
keti_dialogue=pd.read_excel('한국어_연속적_대화_데이터셋.xlsx')

# %%
keti_dialogue.head()
# Out:
#   Unnamed: 0                                    Unnamed: 1 Unnamed: 2  \
# 0   dialog #                                            발화         감정
# 1          S          아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!         분노
# 2        NaN  그럼 직접흡연하는 난 얼마나 안좋겠니? 안그래? 보면 꼭... 지 생각만 하고.         혐오
# 3        NaN                                       손님 왔어요.         중립
# 4        NaN                                       손님? 누구?         중립
#
#    Unnamed: 3  Unnamed: 4      행복  중립  슬픔  공포  혐오  분노  놀람
# 0         NaN         NaN  1030.0 NaN NaN NaN NaN NaN NaN
# 1         NaN         NaN     NaN NaN NaN NaN NaN NaN NaN
# 2         NaN         NaN     NaN NaN NaN NaN NaN NaN NaN
# 3         NaN         NaN     NaN NaN NaN NaN NaN NaN NaN
# 4         NaN         NaN     NaN NaN NaN NaN NaN NaN NaN

# %%
# 첫행을 컬럼으로 바꾸기
new_columns=keti_dialogue.iloc[0]
keti_dialogue=keti_dialogue.rename(columns=new_columns).iloc[:,1:3]

# %%
keti_dialogue.drop(index=0,axis=0,inplace=True)

# %%
keti_dialogue.head()
# Out:
#                                              발화  감정
# 1          아 진짜! 사무실에서 피지 말라니깐! 간접흡연이 얼마나 안좋은데!  분노
# 2  그럼 직접흡연하는 난 얼마나 안좋겠니? 안그래? 보면 꼭... 지 생각만 하고.  혐오
# 3                                       손님 왔어요.  중립
# 4                                       손님? 누구?  중립
# 5                                몰라요. 팀장님 친구래요.  중립

# %%
keti_dialogue["감정"].value_counts()
# Out:
# 감정
# 중립     43786
# 놀람      4866
# 분노      3628
# 슬픔      1972
# 행복      1030
# 혐오       220
# 공포        98
# ㅍ         12
# 분          4
# ㅈ중립        1
# 분ㄴ         1
# 중림         1
# ㄴ중립        1
# 줄          1
# Name: count, dtype: int64

# %%
keti_dialogue=keti_dialogue[keti_dialogue["감정"].isin(["중립","놀람","분노","슬픔","행복","혐오","공포"])]

# %%
# 감정 Label 일정하게 맞춰주기 (감성대화 말뭉치와 통합을 위해)

keti_dialogue["감정"]=np.where(keti_dialogue["감정"].str.match("놀람"),"당황",keti_dialogue["감정"])
keti_dialogue["감정"]=np.where(keti_dialogue["감정"].str.match("공포"),"불안",keti_dialogue["감정"])

# %% [markdown]
# # 데이터셋 합치기

# %%
import csv

#read the txt file
with open('dataset.txt', 'r', encoding='utf-8') as file:
    data = file.read()

# Split the data into lines
lines = data.split('\n')
# Prepare the list for filtered sentences
filtered_sentences = []

# Filter sentences labeled as 1
for line in lines:
    if '|' in line:
        sentence, label = line.split('|', 1)
        if label.strip() == '1':
            filtered_sentences.append(sentence)
hatedf = pd.DataFrame({
    '발화': filtered_sentences,
    '감정': ['분노'] * len(filtered_sentences)
})

hatedf
# Out:
#                                                      발화  감정
# 0                                             좌배 까는건 ㅇㅂ  분노
# 1           개소리야 니가 빨갱이를 옹호하고 드루킹을 ㅇㅇ짓이라고 말못해서 삐진거야 빨갱아  분노
# 2                                    애새끼가 초딩도 아니고 ㅋㅋㅋㅋ   분노
# 3     731부대의 후예라 그런지 가학적인 아이디어는 세계최고임 이래서 애교만 떨어도 돈 ...  분노
# 4                                               재앙이한건햇노  분노
# ...                                                 ...  ..
# 2039                               진짜 저 개성없는 머리는 왜 하는거냐  분노
# 2040                        오나1홀도 애1무 잘해주면 물 나온다 함 해보라ㅏ  분노
# 2041                          좀있으면 100억도 나오겠네 시발 ㅋㅋㅋㅋㅋㅋ  분노
# 2042  세금 내놓으라고 데모질 중 ㅋㅋ간첩, 도둑놈 새끼들이 대통령 해처먹으니까  나도 같...  분노
# 2043                           우리나라교회는 악마들이모여 주뎅이 처벌리고   분노
#
# [2044 rows x 2 columns]

# %%
real_final_df=pd.concat([final_df,keti_dialogue,keti_single,hatedf])

# %%
real_final_df.reset_index(drop=True,inplace=True)

# %%
real_final_df
# Out:
#                                                        발화  감정
# 0       일은 왜 해도 해도 끝이 없을까? 화가 난다.그냥 내가 해결하는 게 나아. 남들한테...  분노
# 1       이번 달에 또 급여가 깎였어! 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나....  분노
# 2       회사에 신입이 들어왔는데 말투가 거슬려. 그런 애를 매일 봐야 한다고 생각하니까 스...  분노
# 3       직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜. 일도 많은 데 정말 분하고 ...  분노
# 4       얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나.상사인 나에게 먼...  분노
# ...                                                   ...  ..
# 148606                               진짜 저 개성없는 머리는 왜 하는거냐  분노
# 148607                        오나1홀도 애1무 잘해주면 물 나온다 함 해보라ㅏ  분노
# 148608                          좀있으면 100억도 나오겠네 시발 ㅋㅋㅋㅋㅋㅋ  분노
# 148609  세금 내놓으라고 데모질 중 ㅋㅋ간첩, 도둑놈 새끼들이 대통령 해처먹으니까  나도 같...  분노
# 148610                           우리나라교회는 악마들이모여 주뎅이 처벌리고   분노
#
# [148611 rows x 2 columns]
# Warning: total number of rows (148611) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
real_final_df["감정"].value_counts()
# Out:
# 감정
# 중립    48616
# 슬픔    27517
# 분노    21754
# 불안    15999
# 당황    14670
# 행복    14406
# 혐오     5649
# Name: count, dtype: int64

# %%
real_final_df.to_csv("sentiment_dialogues.csv")
